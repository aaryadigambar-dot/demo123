# %%
l1 = [23, 45, 67.90, 89, 12, "python" , "java", 23, 45]

# %%
l1
# Out:
# [23, 45, 67.9, 89, 12, 'python', 'java', 23, 45]

# %%
l1[2]
# Out:
# 67.9

# %%
l1[1]
# Out:
# 45

# %%
l1[1] = 100

# %%
l1
# Out:
# [23, 100, 67.9, 89, 12, 'python', 'java', 23, 45]

# %%
l1[-6] = True

# %%
l1
# Out:
# [23, 100, 67.9, 89, True, 'python', 'java', 23, 45]

# %%
l = [21, 23, 45, 67, 89, l1]

# %%
l
# Out:
# [21, 23, 45, 67, 89, [23, 100, 67.9, True, True, 'python', 'java', 23, 45]]

# %%
l[1:4]
# Out:
# [23, 45, 67]

# %%
l[1:-2]
# Out:
# [23, 45, 67]

# %%
l[0:6:2]
# Out:
# [21, 45, 89]

# %%
l
# Out:
# [21, 23, 45, 67, 89, [23, 100, 67.9, True, True, 'python', 'java', 23, 45]]

# %%
l = [21, 23, 45, 67, 89, 11]

# %%
l[::1]
# Out:
# [21, 23, 45, 67, 89, 11]

# %%
l[::-1]
# Out:
# [11, 89, 67, 45, 23, 21]

# %%
l[1:4] = [100, 200, 300]

# %%
l
# Out:
# [21, 100, 200, 300, 89, 11]

# %%
l1 = [12, 34, 56, 23]

# %%
del l1[-2]

# %%
l1
# Out:
# [12, 34, 23]

# %%
del l1

# %%
l1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 l1
#
# NameError: name 'l1' is not defined

# %%
# membership operator

# %%
l
# Out:
# [21, 100, 200, 300, 89, 11]

# %%
89 in l
# Out:
# True

# %%
56 in l
# Out:
# False

# %%
# airthmetic operator

# %%
l
# Out:
# [21, 100, 200, 300, 89, 11]

# %%
l * 2 # repetiton of list
# Out:
# [21, 100, 200, 300, 89, 11, 21, 100, 200, 300, 89, 11]

# %%
'ok' * 3
# Out:
# 'okokok'

# %%
l1 = [12, 34, 23, 67]
l2 = [56, 78, 39, 20]

# %%
l1 + l2
# Out:
# [12, 34, 23, 67, 56, 78, 39, 20]

# %%
# iteration over list

# %%
l
# Out:
# [21, 100, 200, 300, 89, 11]

# %%
# iterate over list and print square of each element

# %%
for i in l:
    print(i**2, end =' ')
# Out:
# 441 10000 40000 90000 7921 121

# %%
for i in l:
    if 1 % 2 == 1:
        print(i, end = ' ')
# Out:
# 21 100 200 300 89 11

# %%
# list comprehension -> [expression for_loop if_condition]

# %%
newl = [i**2 for i in l]

# %%
newl
# Out:
# [441, 10000, 40000, 90000, 7921, 121]

# %%
newl = [i**2 for i in l]
newl
# Out:
# [441, 10000, 40000, 90000, 7921, 121]

# %%
newl2=[i for i in l if i % 2 == 1]

# %%
newl2
# Out:
# [21, 89, 11]

# %%
names = ['Aarya', 'Akshata', 'swaraj', 'sukanya', 'shivraj']

# %%
# create a new list with names which starts with 'a' or 'A'

# %%
for i in names:
    if i.lower().startswith('a'):
        print(i)
# Out:
# Aarya
# Akshata

# %%
new = [i for i in names if i.lower().startswith('a')]
new
# Out:
# ['Aarya', 'Akshata']

# %%
for i in names:
    if i [0] == 'a' or i[0] == 'S'
    print(i)
# Out:
#   Cell In[59], line 2
#     if i [0] == 'a' or i[0] == 'S'
#                                   ^
# SyntaxError: expected ':'

# %%
len(1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 len(1)
#
# TypeError: object of type 'int' has no len()

# %%
l1 = [12, 34, 23, 67]

# %%
len(1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 len(1)
#
# TypeError: object of type 'int' has no len()

# %%
sorted(1, reverse = True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 sorted(1, reverse = True)
#
# TypeError: 'int' object is not iterable

# %%
# list methods

# %%
# append

# %%
l = [21, 100, 200, 300, 89, 11]

# %%
l
# Out:
# [21, 100, 200, 300, 89, 11]

# %%
l.append(1000)

# %%
l
# Out:
# [21, 100, 200, 300, 89, 11, 1000]

# %%
l1 = [1, 2, 3]
l2 = [1, 2, 3]

# %%
l1.append([100, 200])
l2.append([100, 200])

# %%
l1
# Out:
# [1, 2, 3, [100, 200]]

# %%
l2
# Out:
# [1, 2, 3, [100, 200]]

# %%
l1[3]
# Out:
# [100, 200]

# %%
l1[3][1]
# Out:
# 200

# %%
l1[3][1] = 37251289
l1
# Out:
# [1, 2, 3, [100, 37251289]]

# %%
# inser

# %%
l
# Out:
# [21, 100, 200, 300, 89, 11, 1000]

# %%
l.insert(1, 78)
l
# Out:
# [21, 78, 100, 200, 300, 89, 11, 1000]

# %%
l.remove(78)

# %%
l
# Out:
# [21, 100, 200, 300, 89, 11, 1000]

# %%
l.pop()
# Out:
# 1000

# %%
l
# Out:
# [21, 100, 200, 300, 89, 11]

# %%
l.pop(3)
# Out:
# 300

# %%
l.index(89)
# Out:
# 3

# %%
l.sort(reverse = True)
l
# Out:
# [200, 100, 89, 21, 11]
