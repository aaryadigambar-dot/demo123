# %%
import pandas as pd

# %%
roll = pd.Series([1,2,3])
name = pd.Series(['aarya', 'akshata', 'shreya'])
marks = pd.Series([80, 85, 75])

# %%
df = pd.DataFrame({
    'id': roll,
    'name': name,
    'marks':marks
})

# %%
df
# Out:
#    id     name  marks
# 0   1    aarya     80
# 1   2  akshata     85
# 2   3   shreya     75

# %%
df.ndim
# Out:
# 2

# %%
df.shape
# Out:
# (3, 3)

# %%
df.size
# Out:
# 9

# %%
df.columns
# Out:
# Index(['id', 'name', 'marks'], dtype='object')

# %%
"""
url -> https://mitu.co.in/dataset -> will connect to drive folder

download all the dataset starting with student*
put them in the same file folder as ur current working directory

""";

# %%
import urllib.request

url = "https://raw.githubusercontent.com/AdityaThakare72/interns-may-2026/master/daily_codes/week4/student.csv"

urllib.request.urlretrieve(url, "student.csv")

print("Downloaded")
# Out:
# Downloaded

# %%
import os
print(os.listdir())
# Out:
# ['.anaconda', '.conda', '.continuum', '.copilot', '.idlerc', '.ipynb_checkpoints', '.ipython', '.jupyter', '.matplotlib', '.ms-ad', '.nbi', '.packettracer', '.spyder-py3', '.vscode', '.vscode-shared', '3D Objects', 'a1.ipynb', 'a1.txt', 'a2.ipynb', 'aarya.ipynb', 'aarya.p.py', 'aarya1.ipynb', 'anaconda3', 'AppData', 'Application Data', 'Arrays.ipynb', 'bar figure 3.png', 'bar figure.png', 'bar figured 2.png', 'basics.ipynb', 'Cisco Packet Tracer 7.3.0', 'Cisco Packet Tracer 9.0.0', 'Codes.ipynb', 'Contacts', 'Cookies', 'Documents', 'Downloads', 'example.py', 'exception_handling.ipynb', 'Favorites', 'Instagram.lnk', 'IntelGraphicsProfiles', 'Jedi', 'Links', 'Local Settings', 'mah.txt.ipynb', 'mathop.py', 'Music', 'My Documents', 'my pacakages1.py', 'my pacakages2.py', 'my packages1.py', 'my packages2.py', 'mypackages3.py', 'NetHood', 'NTUSER.DAT', 'ntuser.dat.LOG1', 'ntuser.dat.LOG2', 'NTUSER.DAT{987f0b07-9de4-11f0-b62e-facbbbddfca2}.TxR.0.regtrans-ms', 'NTUSER.DAT{987f0b07-9de4-11f0-
# ...

# %%
import pandas as pd

df = pd.read_csv("student.csv")

df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df.shape
# Out:
# (10, 5)

# %%
df.columns
# Out:
# Index(['roll', 'name', 'class', 'marks', 'age'], dtype='object')

# %%
# student1.csv

# %%
import urllib.request

url = "https://raw.githubusercontent.com/AdityaThakare72/interns-may-2026/master/daily_codes/week4/student1.csv"

urllib.request.urlretrieve(url, "student1.csv")

print("Downloaded")
# Out:
# Downloaded

# %%
import pandas as pd

df = pd.read_csv("student1.csv")
df
# Out:
#     1     anil  TE  56.77  22
# 0   2     amit  TE  59.77  21
# 1   3   aniket  BE  76.88  19
# 2   4  ajinkya  TE  69.66  20
# 3   5     asha  TE  63.28  20
# 4   6   ayesha  BE  49.55  20
# 5   7     amar  BE  65.34  19
# 6   8    amita  BE  68.33  23
# 7   9     amol  TE  56.75  20
# 8  10    anmol  BE  78.66  21

# %%
col = ['roll', 'name', 'class', 'marks', 'age']

# %%
df = pd.read_csv('student1.csv', names = col)
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
# student3.tsv

# %%
import urllib.request

url = "https://raw.githubusercontent.com/AdityaThakare72/interns-may-2026/master/daily_codes/week4/student3.tsv"

urllib.request.urlretrieve(url, "student3.tsv")

print("Downloaded")
# Out:
# Downloaded

# %%
df = pd.read_csv(''student3.tsv)
